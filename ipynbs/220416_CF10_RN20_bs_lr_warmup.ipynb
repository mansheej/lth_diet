# %% [markdown]
# ### [04/16/22] CIFAR10 ResNet20 Sweep Batch Size, Learning Rate, and Warmup

# %%
from composer.utils.object_store import ObjectStoreProviderHparams
from lth_diet.exps import TrainExperiment
from lth_diet.utils import utils
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns
from tqdm import tqdm
plt.style.use("default")
rc = {
    "axes.grid": True, "axes.labelpad": 2, "axes.linewidth": 0.8, "axes.spines.right": False, "axes.spines.top": False, 
    "axes.titlepad": 2, "axes.titlesize": "medium", 
    "figure.constrained_layout.use": True, "figure.dpi": 150, "figure.figsize": (4, 3), "figure.titlesize": "medium", 
    "grid.linewidth": 0.8, 'legend.fontsize': "small", "legend.frameon": False, "lines.markeredgecolor": "white", 
    "xtick.major.pad": 2, "xtick.major.size": 3.5, "xtick.major.width": 0.8, 
    "ytick.major.pad": 2, "ytick.major.size": 3.5, "ytick.major.width": 0.8
}
sns.set_theme(style="ticks", palette=sns.color_palette("colorblind"), rc=rc)
object_store = ObjectStoreProviderHparams('google_storage', 'prunes', 'GCS_KEY', ).initialize_object()
bucket_dir = os.environ['OBJECT_STORE_DIR']

# %%
def get_accuracy_val(exp, num_reps, object_store):
    exp_hash = utils.get_hash(exp.name)
    steps_rt, accs_rt = [], []
    for rep in tqdm(range(num_reps)):
        object_store.download_object(f"{bucket_dir}/{exp_hash}/replicate_{rep}/main/log.txt", "temp.txt")
        log = pd.read_table("temp.txt", header=None)[0]
        os.remove("temp.txt")
        steps_t, accs_t = [], []
        for line in log:
            match = re.search('\[EPOCH\]\[step=(\d*)\]: { "accuracy/val": ([+-]?[0-9]*[.]?[0-9]+), \}', line)
            if match:
                steps_t.append(int(match.group(1)))
                accs_t.append(float(match.group(2)))
        steps_rt.append(steps_t)
        accs_rt.append(accs_t)
    steps_rt, accs_rt = np.array(steps_rt), np.array(accs_rt)
    return steps_rt, accs_rt

# %%
data = "cifar10"
model = "resnet20"

# %%
config = f"../configs/{data}_{model}.yaml"
num_replicates = 8
exp = TrainExperiment.create(f=config, cli_args=False)
lrs_bs128 = [0.1, 0.2, 0.4, 0.8, 1.6]
accs_bs128 = []
for lr in lrs_bs128:
    exp.optimizer.lr = lr
    _, accs_rt = get_accuracy_val(exp, num_replicates, object_store)
    accs_bs128.append(accs_rt[:, -1])
accs_bs128 = np.array(accs_bs128)
# Out:
# 100%|██████████| 8/8 [00:07<00:00,  1.05it/s]
# 100%|██████████| 8/8 [00:06<00:00,  1.17it/s]
# 100%|██████████| 8/8 [00:07<00:00,  1.09it/s]
# 100%|██████████| 8/8 [00:06<00:00,  1.30it/s]
# 100%|██████████| 8/8 [00:06<00:00,  1.31it/s]

# %%
config = f"../configs/{data}_{model}_bs1024.yaml"
num_replicates = 8
exp = TrainExperiment.create(f=config, cli_args=False)
lrs_bs1024 = [0.2, 0.4, 0.8, 1.6, 3.2]
accs_bs1024 = []
for lr in lrs_bs1024:
    exp.optimizer.lr = lr
    _, accs_rt = get_accuracy_val(exp, num_replicates, object_store)
    accs_bs1024.append(accs_rt[:, -1])
accs_bs1024 = np.array(accs_bs1024)
# Out:
# 100%|██████████| 8/8 [00:04<00:00,  1.91it/s]
# 100%|██████████| 8/8 [00:04<00:00,  2.00it/s]
# 100%|██████████| 8/8 [00:04<00:00,  1.91it/s]
# 100%|██████████| 8/8 [00:04<00:00,  1.69it/s]
# 100%|██████████| 8/8 [00:04<00:00,  1.95it/s]

# %%
# plt.figure(dpi=300)
ls = []
x, ys = np.array(lrs_bs128), accs_bs128.T
ym, ye = ys.mean(0), ys.std(0)
l = plt.errorbar(np.log2(x*10), ym, yerr=ye, marker="o", elinewidth=1, alpha=0.95)
ls.append(l)
x, ys = np.array(lrs_bs1024), accs_bs1024.T
ym, ye = ys.mean(0), ys.std(0)
l = plt.errorbar(np.log2(x*10), ym, yerr=ye, marker="o", elinewidth=1, alpha=0.9)
ls.append(l)
plt.legend(ls, ["BS 128", "BS 1024"])
plt.xticks([0, 1, 2, 3, 4, 5], [0.1, 0.2, 0.4, 0.8, 1.6, 3.2])
plt.ylim(0.9, 0.92)
plt.xlabel("Base LR")
plt.ylabel("Test Accuracy")
plt.title("CIFAR10 ResNet20")
plt.show()

# %%
config = f"../configs/{data}_{model}_bs1024_warmup.yaml"
num_replicates = 8
exp = TrainExperiment.create(f=config, cli_args=False)
lrs_bs1024 = [0.2, 0.4, 0.8, 1.6, 3.2]
warmups = [96, 384, 1536]
accs_wl = []
for warmup in warmups:
    accs_l = []
    for lr in lrs_bs1024:
        exp.optimizer.lr = lr
        exp.schedulers[0].t_warmup = f"{warmup}ba"
        _, accs_rt = get_accuracy_val(exp, num_replicates, object_store)
        accs_l.append(accs_rt[:, -1])
    accs_wl.append(accs_l)
accs_wl = np.array(accs_wl)
# Out:
# 100%|██████████| 8/8 [00:03<00:00,  2.49it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.50it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.35it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.60it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.44it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.58it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.37it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.47it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.40it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.62it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.15it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.34it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.43it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.34it/s]
# 100%|██████████| 8/8 [00:03<00:00,  2.47it/s]

# %%
plt.figure(figsize=(4.3, 3), dpi=150)
ls = []
x, ys = np.array(lrs_bs128), accs_bs128.T
ym, ye = ys.mean(0), ys.std(0)
l = plt.errorbar(np.log2(x*10), ym, yerr=ye, marker="o", elinewidth=1, alpha=0.95, ls='--')
ls.append(l)
for w, warmup in enumerate(warmups):
    x, ys = np.array(lrs_bs1024), accs_wl[w].T
    ym, ye = ys.mean(0), ys.std(0)
    l = plt.errorbar(np.log2(x*10), ym, yerr=ye, marker="o", elinewidth=1, alpha=0.9-0.05*w)
    ls.append(l)
plt.gcf().legend(ls, ["BS 128, Warmup 0ba", "BS 1024 Warmup 96ba", "BS 1024 Warmup 384ba", "BS 1024 Warmup 1536ba"],
                 ncol= 2, columnspacing=0.5, loc="lower center", bbox_to_anchor=(0.5, -0.15))
plt.xticks([0, 1, 2, 3, 4, 5], [0.1, 0.2, 0.4, 0.8, 1.6, 3.2])
plt.ylim(0.9, 0.92)
plt.xlabel("Base LR")
plt.ylabel("Test Accuracy")
plt.title("CIFAR10 ResNet20")
plt.show()
